# %%
import json
import os
import bz2
import io
from bz2 import BZ2File
import pandas as pd
import numpy as np
import re
from utils import *

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 100)

# %%
files_dir = "../data/impresso-data"
archives = os.listdir(files_dir)
date = "1962"

# %% [markdown]
# * Extract interesting archives

# %%
regex = '(.*196[1-4].*)'
gdl_ = extract_particular_files(archives, regex, 'GDL')      
jdg_ = extract_particular_files(archives, regex, 'JDG')

# %% [markdown]
# * Extract content  and preprocessing

# %%
 df_all, df_gdl, df_jdg = run(gdl_, jdg_, date, files_dir)
# Out:
# GDL-1961.jsonl.bz2 : 51542 articles à extraire
# GDL-1962.jsonl.bz2 : 51816 articles à extraire
# GDL-1963.jsonl.bz2 : 56054 articles à extraire
# GDL-1964.jsonl.bz2 : 54368 articles à extraire
# JDG-1961.jsonl.bz2 : 44528 articles à extraire
# JDG-1962.jsonl.bz2 : 43697 articles à extraire
# JDG-1963.jsonl.bz2 : 43399 articles à extraire
# JDG-1964.jsonl.bz2 : 42831 articles à extraire
#          index  mag        date page                                                                                                 text
# 164350  164350  GDL  1964-05-20    4  BELL ARIA « VILLA NORA » Viale Italia 25 Moderne, accueillante, bourgeoise, merveilleuse situati...
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    mag        date  page  ppage                                                                                                 text  length
# 0  GDL  1961-07-07     1    NaN  I. Ulbricht et le problème de Berlin : « Aucun coup de feu ne sera tiré » BERLIN, 6 juillet. — M...    1119
# 1  GDL  1961-07-07     2    NaN  ROYAL MAIL LINES SERVICES MARITIMES POUR BRÉSIL URUGUAY-ARGENTINE DEPART DE CHERBOURG R. M. S. «...     393
# 2  GDL  1961-07-07     3    NaN  Le dessin d e Constant Meyer — J'ai tenu à faire ce petit détour uniquement pour voir la tète de...     117
# 3  GDL  1961-07-07     4    NaN  LA FORMATION DE TECHNICIENS ETANT URGENTE Yverdon va construire un centre d'enseignement profess...    6002
# 4  GDL  1961-07-07     5    NaN  ASSEMBLÉE GÉNÉRALE DE L'OSEC Un souci pour les dirigeants : trouver de nouvelles ressources L'Of...    3083
# Length df: 61       766
# 193      588
# 152      555
# 183      464
# 153      458
#         ...
# 23801      1
# 10655      1
# 6809       1
# 10562      1
# 16304      1
# Name: length, Length: 13041, dtype: int64
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    mag        date  page  ppage                                                                                                 text  length
# 0  GDL  1961-07-07     1    NaN  I. Ulbricht et le problème de Berlin : « Aucun coup de feu ne sera tiré » BERLIN, 6 juillet. — M...    1119
# 1  GDL  1961-07-07     2    NaN  ROYAL MAIL LINES SERVICES MARITIMES POUR BRÉSIL URUGUAY-ARGENTINE DEPART DE CHERBOURG R. M. S. «...     393
# 2  GDL  1961-07-07     3    NaN  Le dessin d e Constant Meyer — J'ai tenu à faire ce petit détour uniquement pour voir la tète de...     117
# 3  GDL  1961-07-07     4    NaN  LA FORMATION DE TECHNICIENS ETANT URGENTE Yverdon va construire un centre d'enseignement profess...    6002
# 4  GDL  1961-07-07     5    NaN  ASSEMBLÉE GÉNÉRALE DE L'OSEC Un souci pour les dirigeants : trouver de nouvelles ressources L'Of...    3083
# Length df: 61       666
# 193      466
# 152      423
# 111      333
# 153      315
#         ...
# 8773       1
# 11932      1
# 12999      1
# 7834       1
# 8887       1
# Name: length, Length: 11090, dtype: int64
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    mag        date  page  ppage                                                                                                 text  length
# 0  JDG  1961-07-07     1    NaN  Les manifestations en ûlgerie 80 morts et quelque 300 blessés, tel est le bilan officiel de la j...    3553
# 1  JDG  1961-07-07     2    NaN  Assemblée générale de l'OSElC L'Office suisse d'expansion commerciale (OSEC) a tenu son assemblé...    2814
# 2  JDG  1961-07-07     3    NaN  L'URSS signe un traité délensif auec la Corée du nord Moscou, 6. — (AFP) Un traité d'amitié, de ...    3329
# 3  JDG  1961-07-07     4    NaN  La collaboration SuIzer-SLM L'assemblée générale extraordinaire des actionnaires de Sulzer Frère...    4347
# 4  JDG  1961-07-07     5    NaN  es Bourses 6 juillet 1961. La tenue de Wall-Street, ce soir, se révèle en général satisfaisante,...    2585
# Length df: 146      235
# 144      201
# 202      184
# 183      182
# 147      178
#         ...
# 7671       1
# 11601      1
# 8483       1
# 10530      1
# 10679      1
# Name: length, Length: 10590, dtype: int64

# %% [markdown]
# * Keywords filtering

# %%
#keywords_1968 = ['nucléaire', 'nucleaire', "prolifération", 'proliferation', "arme", 'armes', "bombe", 'bombes', "technologie", 'technologies', "traité", 'traite', "international", 
#            "guerre", 'signer', 'signe', 'Londres', 'Moscou', 'Washington', 'ratification', '1976', '1977']
keywords_1962 =['nucléaire', 'Cuba', 'guerre', 'tension','risque', 'bombe', 'guerre nucléaire']
#keywords_1984 = ['nucléaire','initiatives', 'initiative', 'centrale', 'centrales', 'atomique', 'atomiques', 'energie', 'votation']
cleaned_files_dir = "../data/filtered/"
unwanted = ['tableau hebdomadaire']#, '(\/(\s\d*)*\s)*']
archives = os.listdir(files_dir)

# %%
#df_all = load_corpus(cleaned_files_dir + "cleaned_all" + date +".json.bz2")
#df_gdl = load_corpus(cleaned_files_dir + "cleaned_gdl" + date +".json.bz2")
#df_jdg = load_corpus(cleaned_files_dir + "cleaned_jdg" + date +".json.bz2")

# %%
df_all_ = keywords_filtering(df_all, keywords_1962)
df_all_ = unwanted_filtering(df_all_, unwanted)
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (14296, 14)
# =====UNWANTED====
#     mag        date  page  ppage                                                                                                 text  length  keywords  keyword_nucléaire  keyword_Cuba  keyword_guerre  keyword_tension  keyword_risque  keyword_bombe  keyword_guerre nucléaire  garbage
# 5   GDL  1961-07-07     6    NaN  M. KHROUCHTCHEV SIGNE UN TRAITÉ DÉFENSIF AVEC LA CORÉE DU NORD « L'URSS soutient le projet de co...    3651         3                  0             1               1                1               0              0                         0        0
# 12  GDL  1961-07-07     1    NaN  < La conclusion d'un traité de paix est inscrite à l'ordre du jour de l'année 1961 > ON NE MANGE...    3051         3                  0             0               3                0               0              0                         0        0
# 17  GDL  1961-07-07     1    NaN  PAS DE CONCESSIONS RÉELLES Cette phrase contient plus de dynamite que ne répand de miel le reste...    2426         2                  0             0               2                0               0              0                         0        0
# 65  GDL  1961-07-07     1    NaN  LE DROIT ET L'ARBITRAIRE DANS UN DISCOURS prononcé hier, à Moscou, M. Khrouchtchev est revenu, u...    3263         2                  0             0               1                0               1              0                         0        0
# 99  GDL  1961-07-07     6    NaN  Tunisie : Manifestations à Bizerle pour l'évacuation de la base militaire française TUNIS, 6 jui...    1811         3                  0             3               0                0               0              0                         0        0
# 'After keyword filtered: '
# (14296, 14)

# %%
df_gdl_ = keywords_filtering(df_gdl, keywords_1962)
df_gdl_ = unwanted_filtering(df_gdl_, unwanted)
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (7294, 14)
# =====UNWANTED====
#     mag        date  page  ppage                                                                                                 text  length  keywords  keyword_nucléaire  keyword_Cuba  keyword_guerre  keyword_tension  keyword_risque  keyword_bombe  keyword_guerre nucléaire  garbage
# 5   GDL  1961-07-07     6    NaN  M. KHROUCHTCHEV SIGNE UN TRAITÉ DÉFENSIF AVEC LA CORÉE DU NORD « L'URSS soutient le projet de co...    3651         3                  0             1               1                1               0              0                         0        0
# 12  GDL  1961-07-07     1    NaN  < La conclusion d'un traité de paix est inscrite à l'ordre du jour de l'année 1961 > ON NE MANGE...    3051         3                  0             0               3                0               0              0                         0        0
# 17  GDL  1961-07-07     1    NaN  PAS DE CONCESSIONS RÉELLES Cette phrase contient plus de dynamite que ne répand de miel le reste...    2426         2                  0             0               2                0               0              0                         0        0
# 65  GDL  1961-07-07     1    NaN  LE DROIT ET L'ARBITRAIRE DANS UN DISCOURS prononcé hier, à Moscou, M. Khrouchtchev est revenu, u...    3263         2                  0             0               1                0               1              0                         0        0
# 99  GDL  1961-07-07     6    NaN  Tunisie : Manifestations à Bizerle pour l'évacuation de la base militaire française TUNIS, 6 jui...    1811         3                  0             3               0                0               0              0                         0        0
# 'After keyword filtered: '
# (7294, 14)

# %%
df_jdg_ = keywords_filtering(df_jdg, keywords_1962)
df_jdg_ = unwanted_filtering(df_jdg_, unwanted)
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (7002, 14)
# =====UNWANTED====
#      mag        date  page  ppage                                                                                                 text  length  keywords  keyword_nucléaire  keyword_Cuba  keyword_guerre  keyword_tension  keyword_risque  keyword_bombe  keyword_guerre nucléaire  garbage
# 0    JDG  1961-07-07     1    NaN  Les manifestations en ûlgerie 80 morts et quelque 300 blessés, tel est le bilan officiel de la j...    3553         2                  0             0               1                0               1              0                         0        0
# 2    JDG  1961-07-07     3    NaN  L'URSS signe un traité délensif auec la Corée du nord Moscou, 6. — (AFP) Un traité d'amitié, de ...    3329         2                  0             1               1                0               0              0                         0        0
# 12   JDG  1961-07-07     1    NaN  La tension internationale et la convocation du Concile Après une session plétnière qui a duré di...    5086         2                  0             0               0                2               0              0                         0        0
# 89   JDG  1961-07-07     1    NaN  M. Zorine : Pas de guerre pour Berlin New-York, 6. — (AFP) « Une guerre à propos de Berlin paraî...     863         4                  0             0               4                0               0              0                         0        0
# 131  JDG  1961-07-20     5    NaN  L'Euratom et la propulsion navale atomique (—250 La commission de l'Euratom a décidé de particip...    2636         2                  2             0               0                0               0              0                         0        0
# 'After keyword filtered: '
# (7002, 14)

# %% [markdown]
# * Export iramutek

# %%
display(df_all.head())
display(df_gdl.head())
display(df_jdg.head())
# Out:
#    mag        date  page  ppage                                                                                                 text  length  keywords  keyword_nucléaire  keyword_Cuba  keyword_guerre  keyword_tension  keyword_risque  keyword_bombe  keyword_guerre nucléaire
# 0  GDL  1961-07-07     1    NaN  I. Ulbricht et le problème de Berlin : « Aucun coup de feu ne sera tiré » BERLIN, 6 juillet. — M...    1119         0                  0             0               0                0               0              0                         0
# 1  GDL  1961-07-07     2    NaN  ROYAL MAIL LINES SERVICES MARITIMES POUR BRÉSIL URUGUAY-ARGENTINE DEPART DE CHERBOURG R. M. S. «...     393         0                  0             0               0                0               0              0                         0
# 2  GDL  1961-07-07     3    NaN  Le dessin d e Constant Meyer — J'ai tenu à faire ce petit détour uniquement pour voir la tète de...     117         0                  0             0               0                0               0              0                         0
# 3  GDL  1961-07-07     4    NaN  LA FORMATION DE TECHNICIENS ETANT URGENTE Yverdon va construire un centre d'enseignement profess...    6002         0                  0             0               0                0               0              0                         0
# 4  GDL  1961-07-07     5    NaN  ASSEMBLÉE GÉNÉRALE DE L'OSEC Un souci pour les dirigeants : trouver de nouvelles ressources L'Of...    3083         0                  0             0               0                0               0              0                         0
#    mag        date  page  ppage                                                                                                 text  length  keywords  keyword_nucléaire  keyword_Cuba  keyword_guerre  keyword_tension  keyword_risque  keyword_bombe  keyword_guerre nucléaire
# 0  GDL  1961-07-07     1    NaN  I. Ulbricht et le problème de Berlin : « Aucun coup de feu ne sera tiré » BERLIN, 6 juillet. — M...    1119         0                  0             0               0                0               0              0                         0
# 1  GDL  1961-07-07     2    NaN  ROYAL MAIL LINES SERVICES MARITIMES POUR BRÉSIL URUGUAY-ARGENTINE DEPART DE CHERBOURG R. M. S. «...     393         0                  0             0               0                0               0              0                         0
# 2  GDL  1961-07-07     3    NaN  Le dessin d e Constant Meyer — J'ai tenu à faire ce petit détour uniquement pour voir la tète de...     117         0                  0             0               0                0               0              0                         0
# 3  GDL  1961-07-07     4    NaN  LA FORMATION DE TECHNICIENS ETANT URGENTE Yverdon va construire un centre d'enseignement profess...    6002         0                  0             0               0                0               0              0                         0
# 4  GDL  1961-07-07     5    NaN  ASSEMBLÉE GÉNÉRALE DE L'OSEC Un souci pour les dirigeants : trouver de nouvelles ressources L'Of...    3083         0                  0             0               0                0               0              0                         0
#    mag        date  page  ppage                                                                                                 text  length  keywords  keyword_nucléaire  keyword_Cuba  keyword_guerre  keyword_tension  keyword_risque  keyword_bombe  keyword_guerre nucléaire
# 0  JDG  1961-07-07     1    NaN  Les manifestations en ûlgerie 80 morts et quelque 300 blessés, tel est le bilan officiel de la j...    3553         2                  0             0               1                0               1              0                         0
# 1  JDG  1961-07-07     2    NaN  Assemblée générale de l'OSElC L'Office suisse d'expansion commerciale (OSEC) a tenu son assemblé...    2814         1                  0             0               0                0               1              0                         0
# 2  JDG  1961-07-07     3    NaN  L'URSS signe un traité délensif auec la Corée du nord Moscou, 6. — (AFP) Un traité d'amitié, de ...    3329         2                  0             1               1                0               0              0                         0
# 3  JDG  1961-07-07     4    NaN  La collaboration SuIzer-SLM L'assemblée générale extraordinaire des actionnaires de Sulzer Frère...    4347         0                  0             0               0                0               0              0                         0
# 4  JDG  1961-07-07     5    NaN  es Bourses 6 juillet 1961. La tenue de Wall-Street, ce soir, se révèle en général satisfaisante,...    2585         0                  0             0               0                0               0              0                         0

# %%
creating_iramutek_file(df_all_, "../data/iramutek/corpus_all" + date +".txt")
creating_iramutek_file(df_jdg_, "../data/iramutek/corpus_jdg" + date +".txt")
creating_iramutek_file(df_gdl_, "../data/iramutek/corpus_gdl" + date +".txt")
