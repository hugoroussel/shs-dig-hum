# %%
import json
import os
import bz2
import io
from bz2 import BZ2File
import pandas as pd
import numpy as np
import re
import string
from utils import *
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import wordnet
from collections import Counter
import numpy as np
import plotly as py
import plotly.figure_factory as ff
from datetime import datetime
nltk.download('stopwords')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 100)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/matthieubaud/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
files_dir = "../data/impresso-data"
archives = os.listdir(files_dir)
regex='(.*19[3-9].*)'
archives = extract_particular_files(archives, regex)
id_, mag_, date_, page_, text_ =  extract_content(archives, files_dir)
df_ = pd.DataFrame.from_dict(
        {
            'mag': mag_,
            'date': date_,
            'page': page_,
            'text': text_
        })
# Out:
# GDL-1930.jsonl.bz2 : 32479 articles à extraire
# GDL-1931.jsonl.bz2 : 33016 articles à extraire
# GDL-1932.jsonl.bz2 : 32261 articles à extraire
# GDL-1933.jsonl.bz2 : 31841 articles à extraire
# GDL-1934.jsonl.bz2 : 33848 articles à extraire
# GDL-1935.jsonl.bz2 : 31709 articles à extraire
# GDL-1936.jsonl.bz2 : 15755 articles à extraire
# GDL-1937.jsonl.bz2 : 32466 articles à extraire
# GDL-1938.jsonl.bz2 : 30832 articles à extraire
# GDL-1939.jsonl.bz2 : 29946 articles à extraire
# GDL-1940.jsonl.bz2 : 26105 articles à extraire
# GDL-1941.jsonl.bz2 : 26820 articles à extraire
# GDL-1942.jsonl.bz2 : 28164 articles à extraire
# GDL-1943.jsonl.bz2 : 30777 articles à extraire
# GDL-1944.jsonl.bz2 : 34049 articles à extraire
# GDL-1945.jsonl.bz2 : 33710 articles à extraire
# GDL-1946.jsonl.bz2 : 40466 articles à extraire
# GDL-1947.jsonl.bz2 : 41508 articles à extraire
# GDL-1948.jsonl.bz2 : 40291 articles à extraire
# GDL-1949.jsonl.bz2 : 38638 articles à extraire
# GDL-1950.jsonl.bz2 : 38749 articles à extraire
# GDL-1951.jsonl.bz2 : 40675 articles à extraire
# GDL-1952.jsonl.bz2 : 39571 articles à extraire
# GDL-1953.jsonl.bz2 : 39202 articles à extraire
# GDL-1954.jsonl.bz2 : 40889 articles à extraire
# GDL-1955.jsonl.bz2 : 43430 articles à extraire
# GDL-1956.jsonl.bz2 : 44086 articles à extraire
# GDL-1957.jsonl.bz2 : 47321 articles à extraire
# GDL-1958.jsonl.bz2 : 45144 articles à extraire
# GDL-1959.jsonl.bz2 : 45392 articles à extraire
# GDL-1960.jsonl.bz2 : 49781 articles à extraire
# GDL-1961.jsonl.bz2 : 51542 articles à extraire
# GDL-1962.jsonl.bz2 : 51816 articles à extraire
# GDL-1963.jsonl.bz2 : 56054 articles à extraire
# GDL-1964.jsonl.bz2 : 54368 articles à extraire
# GDL-1965.jsonl.bz2 : 51962 articles à extraire
# GDL-1966.jsonl.bz2 : 55456 articles à extraire
# GDL-1967.jsonl.bz2 : 55126 articles à extraire
# GDL-1968.jsonl.bz2 : 51434 articles à extraire
# GDL-1969.jsonl.bz2 : 50467 articles à extraire
# GDL-1970.jsonl.bz2 : 58656 articles à extraire
# GDL-1971.jsonl.bz2 : 54695 articles à extraire
# GDL-1972.jsonl.bz2 : 47024 articles à extraire
# GDL-1973.jsonl.bz2 : 49292 articles à extraire
# GDL-1974.jsonl.bz2 : 45922 articles à extraire
# GDL-1975.jsonl.bz2 : 40363 articles à extraire
# GDL-1976.jsonl.bz2 : 33031 articles à extraire
# GDL-1977.jsonl.bz2 : 46360 articles à extraire
# GDL-1978.jsonl.bz2 : 52100 articles à extraire
# GDL-1979.jsonl.bz2 : 47583 articles à extraire
# GDL-1980.jsonl.bz2 : 49639 articles à extraire
# GDL-1981.jsonl.bz2 : 55490 articles à extraire
# GDL-1982.jsonl.bz2 : 58612 articles à extraire
# GDL-1983.jsonl.bz2 : 58449 articles à extraire
# GDL-1984.jsonl.bz2 : 62830 articles à extraire
# GDL-1985.jsonl.bz2 : 61003 articles à extraire
# GDL-1986.jsonl.bz2 : 65316 articles à extraire
# GDL-1987.jsonl.bz2 : 68609 articles à extraire
# GDL-1988.jsonl.bz2 : 67519 articles à extraire
# GDL-1989.jsonl.bz2 : 69464 articles à extraire
# GDL-1990.jsonl.bz2 : 67016 articles à extraire
# GDL-1991.jsonl.bz2 : 74567 articles à extraire
# GDL-1992.jsonl.bz2 : 78645 articles à extraire
# GDL-1993.jsonl.bz2 : 65764 articles à extraire
# GDL-1994.jsonl.bz2 : 69349 articles à extraire
# GDL-1995.jsonl.bz2 : 65376 articles à extraire
# GDL-1996.jsonl.bz2 : 93430 articles à extraire
# GDL-1997.jsonl.bz2 : 74031 articles à extraire
# GDL-1998.jsonl.bz2 : 11621 articles à extraire
# JDG-1930.jsonl.bz2 : 37470 articles à extraire
# JDG-1931.jsonl.bz2 : 33349 articles à extraire
# JDG-1932.jsonl.bz2 : 32522 articles à extraire
# JDG-1933.jsonl.bz2 : 32383 articles à extraire
# JDG-1934.jsonl.bz2 : 33364 articles à extraire
# JDG-1935.jsonl.bz2 : 32660 articles à extraire
# JDG-1936.jsonl.bz2 : 32990 articles à extraire
# JDG-1937.jsonl.bz2 : 33688 articles à extraire
# JDG-1938.jsonl.bz2 : 32131 articles à extraire
# JDG-1939.jsonl.bz2 : 28127 articles à extraire
# JDG-1940.jsonl.bz2 : 24609 articles à extraire
# JDG-1941.jsonl.bz2 : 25230 articles à extraire
# JDG-1942.jsonl.bz2 : 28060 articles à extraire
# JDG-1943.jsonl.bz2 : 28169 articles à extraire
# JDG-1944.jsonl.bz2 : 28198 articles à extraire
# JDG-1945.jsonl.bz2 : 27421 articles à extraire
# JDG-1946.jsonl.bz2 : 29570 articles à extraire
# JDG-1947.jsonl.bz2 : 30397 articles à extraire
# JDG-1948.jsonl.bz2 : 30139 articles à extraire
# JDG-1949.jsonl.bz2 : 29623 articles à extraire
# JDG-1950.jsonl.bz2 : 31956 articles à extraire
# JDG-1951.jsonl.bz2 : 32934 articles à extraire
# JDG-1952.jsonl.bz2 : 37481 articles à extraire
# JDG-1953.jsonl.bz2 : 37376 articles à extraire
# JDG-1954.jsonl.bz2 : 38122 articles à extraire
# JDG-1955.jsonl.bz2 : 41072 articles à extraire
# JDG-1956.jsonl.bz2 : 39761 articles à extraire
# JDG-1957.jsonl.bz2 : 41687 articles à extraire
# JDG-1958.jsonl.bz2 : 41511 articles à extraire
# JDG-1959.jsonl.bz2 : 41985 articles à extraire
# JDG-1960.jsonl.bz2 : 40961 articles à extraire
# JDG-1961.jsonl.bz2 : 44528 articles à extraire
# JDG-1962.jsonl.bz2 : 43697 articles à extraire
# JDG-1963.jsonl.bz2 : 43399 articles à extraire
# JDG-1964.jsonl.bz2 : 42831 articles à extraire
# JDG-1965.jsonl.bz2 : 44262 articles à extraire
# JDG-1966.jsonl.bz2 : 46881 articles à extraire
# JDG-1967.jsonl.bz2 : 44754 articles à extraire
# JDG-1968.jsonl.bz2 : 45200 articles à extraire
# JDG-1969.jsonl.bz2 : 47098 articles à extraire
# JDG-1970.jsonl.bz2 : 45544 articles à extraire
# JDG-1971.jsonl.bz2 : 44609 articles à extraire
# JDG-1972.jsonl.bz2 : 45846 articles à extraire
# JDG-1973.jsonl.bz2 : 47244 articles à extraire
# JDG-1974.jsonl.bz2 : 47635 articles à extraire
# JDG-1975.jsonl.bz2 : 43822 articles à extraire
# JDG-1976.jsonl.bz2 : 46363 articles à extraire
# JDG-1977.jsonl.bz2 : 46117 articles à extraire
# JDG-1978.jsonl.bz2 : 49528 articles à extraire
# JDG-1979.jsonl.bz2 : 47359 articles à extraire
# JDG-1980.jsonl.bz2 : 49477 articles à extraire
# JDG-1981.jsonl.bz2 : 52220 articles à extraire
# JDG-1982.jsonl.bz2 : 55201 articles à extraire
# JDG-1983.jsonl.bz2 : 55278 articles à extraire
# JDG-1984.jsonl.bz2 : 57551 articles à extraire
# JDG-1985.jsonl.bz2 : 60329 articles à extraire
# JDG-1986.jsonl.bz2 : 66144 articles à extraire
# JDG-1987.jsonl.bz2 : 68753 articles à extraire
# JDG-1988.jsonl.bz2 : 69316 articles à extraire
# JDG-1989.jsonl.bz2 : 71376 articles à extraire
# JDG-1990.jsonl.bz2 : 72869 articles à extraire
# JDG-1991.jsonl.bz2 : 72939 articles à extraire
# JDG-1992.jsonl.bz2 : 71017 articles à extraire
# JDG-1993.jsonl.bz2 : 65252 articles à extraire
# JDG-1994.jsonl.bz2 : 68405 articles à extraire
# JDG-1995.jsonl.bz2 : 73334 articles à extraire
# JDG-1996.jsonl.bz2 : 72260 articles à extraire
# JDG-1997.jsonl.bz2 : 72758 articles à extraire
# JDG-1998.jsonl.bz2 : 11621 articles à extraire

# %% [markdown]
# * Nuclear topics extraction
#
# La premiere étape est d'identifier parmis les articles ceux en rapport a notre sujet. Pour ce faire nous avons filtrer les articles par comptage de mot clef très psécifique au sujet et étant sur d'être employé: ['nucléaire', "nucleaire", 'atomique']

# %%
def check_keywords(df, keywords):
    regex = re.compile("keyword_.*")
    kw_cols = list(filter(regex.match, df.columns))
    display(df[kw_cols].astype(bool).sum(axis=0))
    return df.drop(kw_cols, axis=1)

# %%
# Keywords filtering and preprocessing
#unwanted = ['tableau hebdomadaire']
#df_ = unwanted_filtering(df_, unwanted)

keywords_nuclear =['nucléaire', "nucleaire", 'atomique']
df_nuclear = keywords_filtering(df_, keywords_nuclear)
df_nuclear = preprocessing('only_nuclear', df_nuclear)
df_nuclear = keywords_filtering(df_nuclear, keywords_nuclear)

#Preprocess dates
df_nuclear.sort_values(by='date', inplace=True)
df_nuclear['date'] =  pd.to_datetime(df_nuclear['date'], format='%Y-%m-%d')

display(df_nuclear.head())
display(df_nuclear.dtypes)
display(df_nuclear.shape)

# %%
#df_nuclear.to_csv("data/nuclear_data.csv")
df_nuclear = pd.read_csv("data/nuclear_data.csv")
df_nuclear.drop("Unnamed: 0", axis=1, inplace=True)
#Preprocess dates
df_nuclear.sort_values(by='date', inplace=True)
df_nuclear['date'] =  pd.to_datetime(df_nuclear['date'], format='%Y-%m-%d')

display(df_nuclear.head())
display(df_nuclear.dtypes)
display(df_nuclear.shape)

unwanted = ['tableau hebdomadaire']
df_nuclear = unwanted_filtering(df_nuclear, unwanted)
keywords_nuclear =['nucléaire', "nucleaire", 'atomique']
df_nuclear = keywords_filtering(df_nuclear, keywords_nuclear)
df_nuclear = check_keywords(df_nuclear, keywords_nuclear)
display(df_nuclear.head())
display(df_nuclear.dtypes)
display(df_nuclear.shape)
# Out:
#    mag       date  page  ppage                                                                                                 text  length
# 0  GDL 1930-01-11     4    NaN  Un problème de circulation LES ACTUALITÉS MÉDICALES Nous empruntons au journal « Le Tempe » cett...   15508
# 1  GDL 1930-01-23     3    NaN  Paternité et empreintes digitales Deux médecins allemands appartenant tous deux à l'Institut ana...    1680
# 2  GDL 1930-01-25     3    NaN  Conseils aux lymphatiques QUESTIONS D'HYGIÈNE La lymphe est appelée le sang blanc. Elle circule ...    6472
# 3  GDL 1930-02-05     3    NaN  LE SOLEIL ENSEVELI FEUILLETON DE LA 7 « GAZETTE DE LAUSANNE » Noëlle Roger Alors je vis Kerluoe ...    7557
# 4  JDG 1930-02-19     2    NaN  FEUILLETON DU JOURNAL DE GENEVE Les problèmes de la vie Y a-t-il une crise du transformisme ? La...    7113
# mag               object
# date      datetime64[ns]
# page               int64
# ppage            float64
# text              object
# length             int64
# dtype: object
# (71713, 6)
# =====UNWANTED====
# 'After keyword filtered: '
# (71712, 6)
# ===KEYWORDS===
# 'After keyword filtered: '
# (71712, 10)
# keyword_nucléaire    51661
# keyword_nucleaire      576
# keyword_atomique     33505
# dtype: int64
#    mag       date  page  ppage                                                                                                 text  length  keywords
# 0  GDL 1930-01-11     4    NaN  Un problème de circulation LES ACTUALITÉS MÉDICALES Nous empruntons au journal « Le Tempe » cett...   15508         1
# 1  GDL 1930-01-23     3    NaN  Paternité et empreintes digitales Deux médecins allemands appartenant tous deux à l'Institut ana...    1680         1
# 2  GDL 1930-01-25     3    NaN  Conseils aux lymphatiques QUESTIONS D'HYGIÈNE La lymphe est appelée le sang blanc. Elle circule ...    6472         2
# 3  GDL 1930-02-05     3    NaN  LE SOLEIL ENSEVELI FEUILLETON DE LA 7 « GAZETTE DE LAUSANNE » Noëlle Roger Alors je vis Kerluoe ...    7557         1
# 4  JDG 1930-02-19     2    NaN  FEUILLETON DU JOURNAL DE GENEVE Les problèmes de la vie Y a-t-il une crise du transformisme ? La...    7113         1
# mag                 object
# date        datetime64[ns]
# page                 int64
# ppage              float64
# text                object
# length               int64
# keywords             int64
# dtype: object
# (71712, 7)

# %% [markdown]
# * Separate civil from militaire
#
# Maintenant nous pouvons séparer par une deuxieme étape de filtrage un corpus rassemblant les articles du nucléaire civile, du nucléaire militaire et enfin ceux qui traite les deux. Ces derniers peuvent arrivé souvent lorsque des questions sur l'un impacte l'autre.

# %%
# Select civil from nuclear 
keywords_civil = ['energie atomique', 'énergie atomique', 'énergie nucléaire', 'centrale']
df_civil = keywords_filtering(df_nuclear, keywords_civil)
df_civil = check_keywords(df_civil, keywords_civil)
display(df_civil.head())
display(df_civil.dtypes)
display(df_civil.shape)
#df_civil.to_csv("data/nuclear_civil_data.csv")
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (25549, 11)
# keyword_energie atomique       692
# keyword_énergie atomique      8409
# keyword_énergie nucléaire     6027
# keyword_centrale             16492
# dtype: int64
#     mag       date  page  ppage                                                                                                 text  length  keywords
# 9   JDG 1930-03-08     4    NaN  CONFÉDÉRATION Pour l'humanité souffrante. — Récemment la Société de secours de Winterthoirri la ...    2841         1
# 24  JDG 1930-12-17     4    NaN  LES CONFÉRENCES Les conférences de l'Aula Le Sinanthroous Dans le numéro de samedi écoulé, M. le...    7145         1
# 41  JDG 1931-07-06     3    NaN  Université Durant le semestre d'été, l'Institut de physique a tenu régulièrement ses « Colloques...    1674         1
# 47  GDL 1931-08-07     1    NaN  Le nouvel Institut de biologie physico-chimique de Parts Rue Pierre-Curie, face aux Instituts du...    8604         1
# 53  JDG 1931-11-06     6    NaN  LES CONFERENCES Le sentiment religieux Comme suite à l'enquête de M. Pierre Bovet sur le sentime...     928         1
# mag                 object
# date        datetime64[ns]
# page                 int64
# ppage              float64
# text                object
# length               int64
# keywords             int64
# dtype: object
# (25549, 7)

# %%
# Select military from nuclear 
keywords_militaire = ['arme', 'bombe', 'guerre atomique', 'guerre nucléaire']
df_militaire = keywords_filtering(df_nuclear, keywords_militaire)
df_militaire = check_keywords(df_militaire, keywords_militaire)
display(df_militaire.head())
display(df_militaire.dtypes)
display(df_militaire.shape)
#df_militaire.to_csv("data/nuclear_militaire_data.csv")
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (31461, 15)
# keyword_energie atomique       206
# keyword_énergie atomique      2705
# keyword_énergie nucléaire     1106
# keyword_centrale              3336
# keyword_arme                 26249
# keyword_bombe                 9463
# keyword_guerre atomique       1065
# keyword_guerre nucléaire      1229
# dtype: int64
#     mag       date  page  ppage                                                                                                 text  length  keywords
# 3   GDL 1930-02-05     3    NaN  LE SOLEIL ENSEVELI FEUILLETON DE LA 7 « GAZETTE DE LAUSANNE » Noëlle Roger Alors je vis Kerluoe ...    7557         1
# 37  GDL 1931-06-07     1    NaN  Chronique scientifique f par Alphonse BERNOUD je pi Le bombardement cosmique Jour et nuit, l'ann...   10875         1
# 52  JDG 1931-10-28     4    NaN  La vie d'un savant « John Briquet Le Journal de Genève a déjà annoncé le décès de John Briquet e...   11709         1
# 54  GDL 1931-11-15     4    NaN  Echos scientifiques Un drame cosmique Sir Arthur Eddington, président de la Société de physique ...    6292         3
# 63  GDL 1932-01-25     3    NaN  Les conférence * académiques Conférence du Dr E. Rist Le grincement de dents cher, les malades à...    4514         1
# mag                 object
# date        datetime64[ns]
# page                 int64
# ppage              float64
# text                object
# length               int64
# keywords             int64
# dtype: object
# (31461, 7)

# %%
df_both = df_militaire[df_militaire.isin(df_civil)].dropna()
df_both
display(df_both.head())
display(df_both.dtypes)
display(df_both.shape)
#df_both.to_csv("data/nuclear_both_data.csv")
df_both[df_both['mag']== 'JDG'].shape
# Out:
#        mag       date  page  ppage                                                                                                 text  length  keywords
# 27195  JDG 1965-12-13   1.0    5.0  Les constr-ucteuredu « Concorde » craignent les radiations Les avions de transport civils supers...  7021.0       1.0
# 35928  JDG 1973-09-27   1.0    3.0  Le Traité de non-prolifération réveille M. Franz-Josef Strauss De Bonn : Jiïrg Bissegger Signé e...  4351.0       2.0
# 37082  JDG 1974-10-21   1.0    5.0  Les Arabes se sentent calomniés « GUERRE DU PÉTROLE » De Beyrouth : Edouard Saab Les milieux pol...  4440.0       1.0
# 38144  JDG 1975-09-02   1.0    7.0  Paris pense ce régions » il oublie les peuples ! DE LA BRETAGNE A LA CORSE De Paris : Thierry Pf...  4902.0       1.0
# 39180  JDG 1976-09-16   1.0    3.0  LES ÉTATS-UNIS DEVANT LA PROLIFÉRATION NUCLÉAIRE (III) L'impasse de la persuasion ... et celle d...  5134.0       2.0
# mag                 object
# date        datetime64[ns]
# page               float64
# ppage              float64
# text                object
# length             float64
# keywords           float64
# dtype: object
# (14, 7)
# (14, 7)

# %%
#Check shapes for interception articles
display(keywords_filtering(df_nuclear, keywords_civil + keywords_militaire).head(2))
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (50779, 15)
#    mag       date  page  ppage                                                                                                 text  length  keywords  keyword_energie atomique  keyword_énergie atomique  keyword_énergie nucléaire  keyword_centrale  keyword_arme  keyword_bombe  keyword_guerre atomique  keyword_guerre nucléaire
# 3  GDL 1930-02-05     3    NaN  LE SOLEIL ENSEVELI FEUILLETON DE LA 7 « GAZETTE DE LAUSANNE » Noëlle Roger Alors je vis Kerluoe ...    7557         1                         0                         0                          0                 0             1              0                        0                         0
# 9  JDG 1930-03-08     4    NaN  CONFÉDÉRATION Pour l'humanité souffrante. — Récemment la Société de secours de Winterthoirri la ...    2841         1                         0                         0                          0                 1             0              0                        0                         0

# %% [markdown]
# Le nucléaire militaire est globalement plus traité que le nucléaire civile. Nous remarquons 14 articles traitant à la fois du civile et du militaire.
# - 72k articles pour le nucléaire
# - 26k nucléaire civile
# - 31k nucléaire militaire
# - 14 articles deux domaines

# %% [markdown]
# * Plot the count evolution of article along the time
#
# Nous pouvons facilement afficher l'evolution du nombre d'article concernant le nucléaire au cours du temps. Nous allons également le faire plus précisment sur les corpus du nucléair et du civle. Finalement la séparation entre les journaux peut petre interessant.

# %%
def plots_on_key_func(key, func, name):
    #Count nucleair, civil, militaire
    plt.figure(figsize=(16, 6))
    plt.title(name + "du nombre d'article par jour")
    plt.plot(df_nuclear.groupby('date')[['text']].apply(func), label='nucléaire')
    plt.plot(df_civil.groupby('date')[['text']].apply(func), label='civile')
    plt.plot(df_militaire.groupby('date')[['text']].apply(func), label='militaire')
    plt.legend()
    plt.show()
    
    # Par journal: Journal de geneve & Gazette de Lausanne
    plt.figure(figsize=(16, 6))
    plt.title(name + "du nombre d'article par jour par corpus pour JDL")
    plt.plot(df_nuclear[df_nuclear['mag'] == 'JDG'].groupby('date').apply(func), style='-', label='nucléaire JDG')
    plt.plot(df_civil[df_civil['mag'] == 'JDG'].groupby('date').apply(func), style='-', label='civile JDG')
    plt.plot(df_militaire[df_militaire['mag'] == 'JDG'].groupby('date').apply(func), style='-', label='militaire JDG')

    plt.title(name + "du nombre d'article par jour par corpus pour GDL")
    plt.plot(df_nuclear[df_nuclear['mag'] == 'GDL'].groupby('date').apply(func), style='--', label='nucléaire GDL')
    plt.plot(df_civil[df_civil['mag'] == 'GDL'].groupby('date').apply(func), style='--', label='civile GDL')
    plt.plot(df_militaire[df_militaire['mag'] == 'GDL'].groupby('date').apply(func), style='--', label='nucl"aire GDL')
    plt.legend()

    plt.show()

# %%
#Compte du nombre d'articles par jour
plt.figure(figsize=(16, 6))
plt.title("Compte du nombre d'article par jour")
plt.plot(df_nuclear.groupby('date')[['text']].count(), label='nucléaire')
plt.plot(df_civil.groupby('date')[['text']].count(), label='civile')
plt.plot(df_militaire.groupby('date')[['text']].count(), label='militaire')
plt.legend()
plt.show()

# %%
# Par journal: Journal de geneve & Gazette de Lausanne
plt.figure(figsize=(16, 6))
plt.title("Compte du nombre d'article par jour par corpus pour JDL")
plt.plot(df_nuclear[df_nuclear['mag'] == 'JDG'].groupby('date')[['text']].count(), label='nucléaire')
plt.plot(df_civil[df_civil['mag'] == 'JDG'].groupby('date')[['text']].count(), label='civile')
plt.plot(df_militaire[df_militaire['mag'] == 'JDG'].groupby('date')[['text']].count(), label='militaire')
plt.legend()

plt.show()

plt.figure(figsize=(16, 6))
plt.title("Compte du nombre d'article par jour par corpus pour GDL")
plt.plot(df_nuclear[df_nuclear['mag'] == 'GDL'].groupby('date')[['text']].count(), label='nucléaire')
plt.plot(df_civil[df_civil['mag'] == 'GDL'].groupby('date')[['text']].count(), label='civile')
plt.plot(df_militaire[df_militaire['mag'] == 'GDL'].groupby('date')[['text']].count(), label='militaire')
plt.legend()

plt.show()

# %%
# Plot des 100 jours avec le plus d'articles
plt.figure(figsize=(10, 4))
plt.plot(df_nuclear.groupby('date')[['text']].count().nlargest(100, columns='text').sort_index(), label='nucléaire')
plt.show()
plt.figure(figsize=(10, 4))

plt.plot(df_civil.groupby('date')[['text']].count().nlargest(100, columns='text').sort_index(), label='civile')
plt.show()
plt.figure(figsize=(10, 4))
plt.plot(df_militaire.groupby('date')[['text']].count().nlargest(100, columns='text').sort_index(), label='militaire')
plt.show()

# %%
display(df_nuclear.groupby('date')[['text']].count().describe())
display(df_civil.groupby('date')[['text']].count().describe())
display(df_militaire.groupby('date')[['text']].count().describe())
# Out:
#                text
# count  14928.000000
# mean       4.803859
# std        3.561626
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max       50.000000
#               text
# count  9864.000000
# mean      2.590126
# std       2.084883
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max      38.000000
#                text
# count  11181.000000
# mean       2.813791
# std        1.990638
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max       18.000000

# %% [markdown]
# * Plot pages importance
#
# Nous pouvons également afficher la proportion de première/deuxième page des articles. En effet la présence d'article à cette position est signe de l'importance de l'évènement ou du sujet traité.

# %%
#Moyenne de la position 
plt.figure(figsize=(16, 6))
plt.title("Moyenne de la position des articles par jour ")
plt.plot(df_nuclear.groupby('date')[['page']].mean(), label='nucléaire')
plt.plot(df_civil.groupby('date')[['page']].mean(), label='civile')
plt.plot(df_militaire.groupby('date')[['page']].mean(), label='militaire')
plt.legend()
plt.show()

# %%
#Nombre d'article en tête d'affiche de la position 
plt.figure(figsize=(16, 6))
plt.title("Nombre d'article en tête d'affiche par jour ")
temp_nuclear = df_nuclear[df_nuclear['page'] > 2]
temp_civil = df_civil[df_nuclear['page'] > 2]
temp_militaire = df_militaire[df_nuclear['page'] > 2]
print("test")
plt.plot(temp_nuclear.groupby('date')[['page']].count(), label='nucléaire')
plt.plot(temp_civil.groupby('date')[['page']].count(), label='civile')
plt.plot(temp_militaire.groupby('date')[['page']].count(), label='militaire')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# test

# %%
df_civil.page.unique()
# Out:
# array([ 4,  3,  1,  6, 11,  7,  5,  9, 10,  2,  8, 12, 14, 16, 13, 15, 18,
#        20, 27, 23, 19, 34, 17, 30, 22, 32, 21, 25, 26, 31, 24, 29, 28, 42,
#        33, 37, 49, 40, 51, 35, 36, 64, 58, 59, 38, 39, 43, 44, 48, 46, 41,
#        65, 67, 52, 45, 66, 50, 62, 76, 75, 47, 53, 54, 57])

# %% [markdown]
# * Plot the info about the length of articles
#
# Nous pouvons afficher la taille moyenne des articles par jour. Nous pouvons aussi regarde si la longueur des articles chnage au cours du temps.

# %%
#Moyenne de la taille
plt.figure(figsize=(16, 6))
plt.title("Moyenne de la taille des articles par jour ")
plt.plot(df_nuclear.groupby('date')[['length']].mean(), label='nucléaire')
plt.plot(df_civil.groupby('date')[['length']].mean(), label='civile')
plt.plot(df_militaire.groupby('date')[['length']].mean(), label='militaire')
plt.legend()
plt.show()

# %%
#Moyenne cumulative de la taille
plt.figure(figsize=(16, 6))
plt.title("Moyenne cumulative de la taille des articles par jour ")
#plt.plot(df_nuclear.groupby('date')[['length']].mean().expanding().mean(), label='nucléaire')
plt.plot(df_civil.groupby('date')[['length']].mean().expanding().mean(), label='civile')
plt.plot(df_militaire.groupby('date')[['length']].mean().expanding().mean(), label='militaire')
plt.legend()
plt.show()

# %% [markdown]
# * Select important dates and analyse
#
# De ces différents graphes nous pouvons à présent nous concertrer sur les évènements les plus importants et avoir une variance prise depuis nos résultat

# %%
#Afficher les 10 jours par domaines correspond au nopmbre d'article le plus grand
display(df_nuclear.groupby('date')[['text']].count().nlargest(10, columns='text').sort_index())
display(df_civil.groupby('date')[['text']].count().nlargest(10, columns='text').sort_index())
display(df_militaire.groupby('date')[['text']].count().nlargest(10, columns='text').sort_index())
# Out:
#             text
# date
# 1955-08-08    27
# 1957-11-28    31
# 1959-06-24    33
# 1966-12-29    32
# 1979-02-09    29
# 1979-02-14    30
# 1984-09-11    50
# 1986-05-01    32
# 1986-05-02    29
# 1992-04-29    30
#             text
# date
# 1955-08-08    21
# 1955-08-12    22
# 1957-11-28    22
# 1959-06-24    23
# 1979-02-14    21
# 1979-04-03    19
# 1984-09-11    38
# 1986-05-01    22
# 1986-05-02    19
# 1988-03-03    19
#             text
# date
# 1945-08-09    15
# 1945-08-10    18
# 1957-04-13    17
# 1957-05-18    14
# 1957-07-06    14
# 1962-03-13    15
# 1962-03-24    16
# 1964-10-19    15
# 1985-08-06    15
# 1986-01-17    18

# %% [markdown]
# Depuis ce table nous pouvons récupérer les dates importantes. Le nombre d'occurence des articles, leur position dans le journal ainsi que sa longueur sont des indicateurs de l'importance de l'article.

# %%
#Utils
events_militaire ={"ww2": ('1939-01-01', '1945-01-01'),
                    "cuba": ('1962-01-01', '1962-12-01')}
events_civils = {"lucens": ('1969-01-01', '1969-03-15'),
                "chernobyl": ('1986-01-01', '1987-01-01')}

def select_dates(df, start, end):
    res = df.copy()
    mask = (res['date'] >= start) & (res['date'] < end)
    res =  res.loc[mask]
    return res.set_index("date")

# %%
#militaire
cuba = select_dates(df_militaire, 
                     start=events_militaire['cuba'][0], 
                     end=events_militaire['cuba'][1])
ww2 = select_dates(df_militaire, 
                     start=events_militaire['ww2'][0], 
                     end=events_militaire['ww2'][1])


#Civil
lucens = select_dates(df_civil, 
                     start=events_civils['lucens'][0], 
                     end=events_civils['lucens'][1])
display(lucens.shape)
chernobyl = select_dates(df_civil, 
                     start=events_civils['chernobyl'][0], 
                     end=events_civils['chernobyl'][1])
# Out:
# (45, 6)

# %% [markdown]
# * Dendogramme

# %%
def get_french_stopwords():
    with open("data/stopwords_french.txt") as file:
        stopwords = [line[:-1] for line in file]
    return stopwords


def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
temp = keywords_filtering(lucens, ['lucens'])
data = ' '.join(temp["text"])

stopwords= get_french_stopwords()

#Stemmize the words
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("french")


totalvocab_stemmed = []
totalvocab_tokenized = []
text = "".join([word.lower() for word in data if word not in string.punctuation])
tokenize = re.split("\W+", text)
text = [wn.lemmatize(word) for word in tokenize if word not in stopwords]
print(text[:10])
for i in text:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)
    
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (6, 7)
# ['fuite', 'poussiètes', 'radioactives', 'berne', '22', 'at', 'service', 'dalarme', 'commission', 'surveillance']
# there are 1056 items in vocab_frame

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Remove digit
#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.9, max_features=200000,
                                 min_df=0.1, stop_words=stopwords,
                                 use_idf=True, tokenizer=tokenize_only, ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(text) #fit the vectorizer to synopses

print(tfidf_matrix.shape)

terms = tfidf_vectorizer.get_feature_names()

from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-220-b13555df60b7> in <module>
#       7                                  use_idf=True,ngram_range=(1,3))
#       8
# ----> 9 tfidf_matrix = tfidf_vectorizer.fit_transform(text) #fit the vectorizer to synopses
#      10
#      11 print(tfidf_matrix.shape)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1857         """
#    1858         self._check_params()
# -> 1859         X = super().fit_transform(raw_documents)
#    1860         self._tfidf.fit(X)
#    1861         # X is already a transformed view of raw_documents so
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1239                                                        max_doc_count,
#    1240                                                        min_doc_count,
# -> 1241                                                        max_features)
#    1242
#    1243             self.vocabulary_ = vocabulary
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _limit_features(self, X, vocabulary, high, low, limit)
#    1107         kept_indices = np.where(mask)[0]
#    1108         if len(kept_indices) == 0:
# -> 1109             raise ValueError("After pruning, no terms remain. Try a lower"
#    1110                              " min_df or a higher max_df.")
#    1111         return X[:, kept_indices], removed_terms
#
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.

# %%
from scipy.cluster.hierarchy import ward, dendrogram

linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=titles);

plt.tick_params(\
    axis= 'x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

#uncomment below to save figure
plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-197-8b64de08c396> in <module>
#       1 from scipy.cluster.hierarchy import ward, dendrogram
#       2
# ----> 3 linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances
#       4
#       5 fig, ax = plt.subplots(figsize=(15, 20)) # set size
#
# NameError: name 'dist' is not defined

# %%
stopwords= get_french_stopwords()

# additional stopwords to be removed manually.
#file = open('Corpus.txt', 'r')
#moreStopwords = file.read().splitlines()
ps = nltk.PorterStemmer()
wn = nltk.WordNetLemmatizer()

#data = PyPDF4.PdfFileReader(open('ReadyPlayerOne.pdf', 'rb'))
temp = keywords_filtering(lucens, ['lucens'])
pageData = ' '.join(temp["text"])
#for page in data.pages:
#pageData += page.extractText()


def clean_text(text):
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    tokenize = re.split("\W+", text)
    text = [wn.lemmatize(word) for word in tokenize if word not in stopwords]
    # Remove digit
    text = [word for word in text if not re.match('[0-9].*', word)]
    text = [word for word in text if len(word) > 4]
    print(text[:100])
    
    #final = [word for word in text if word not in moreStopwords]
    # Accessing wordnet synset corpora to find the meaning of the words.
    # lemmas = []
    # for token in final:
    #     lemmas += [synset.lemmas()[0].name() for synset in wordnet.synsets(token)]
    # return list(set(lemmas))  # returns unique words
    # return list(lemmas)
    return text #final


# get most common words & plot them on bar graph
filter_data = clean_text(pageData)
most_common_words = [word for word, word_count in Counter(filter_data).most_common(25)]


# Creating Dendogram
X = np.random.rand(25, 25)
fig = ff.create_dendrogram(X, orientation='bottom', 
labels=most_common_words)
fig['layout'].update({'width': 800, 'height': 800})
py.offline.plot(fig, filename='dendrogram_with_labels')
# Out:
# ===KEYWORDS===
# 'After keyword filtered: '
# (6, 7)
# ['fuite', 'poussiètes', 'radioactives', 'berne', 'service', 'dalarme', 'commission', 'surveillance', 'radioactivité', 'direction', 'lenergie', 'ouestsuisse', 'commission', 'fédérale', 'sécurité', 'installation', 'atomiques', 'question', 'dénergie', 'atomique', 'publié', 'communiqué', 'incident', 'produit', 'mardi', 'réacteur', 'centrale', 'nucléaire', 'expérimentale', 'lucens', 'systèmes', 'sécurité', 'immédiatement', 'arrêté', 'linstallation', 'toutefois', 'empêché', 'quune', 'petite', 'quantité', 'produit', 'radioactif', 'échappée', 'cavernes', 'organes', 'sécurité', 'compétents', 'alertés', 'envoyé', 'immédiatement', 'spécialistes', 'lieux', 'alentours', 'linstallation', 'régulièrement', 'contrôlés', 'groupe', 'service', 'dalarme', 'commission', 'fédérale', 'radioactivité', 'résultats', 'mesures', 'indiquent', 'nexiste', 'danger', 'population', 'section', 'sécurité', 'installation', 'atomiques', 'membre', 'commission', 'fédérale', 'sécurité', 'installation', 'atomiques', 'également', 'rendus', 'lucens', 'prévoir', 'faire', 'exécuter', 'dentente', 'direction', 'lexploitation', 'intervention', 'simposent', 'létendue', 'dégâts', 'matériels', 'origine', 'déterminées', 'caverne', 'réacteur', 'accessible', 'membre', 'lexploitation', 'blessé']
# 'dendrogram_with_labels.html'

# %% [markdown]
# * Create iramutek files

# %%
creating_iramutek_file(df_all_, "../data/iramutek/corpus_all" + date +".txt")
creating_iramutek_file(df_jdg_, "../data/iramutek/corpus_jdg" + date +".txt")
creating_iramutek_file(df_gdl_, "../data/iramutek/corpus_gdl" + date +".txt")
